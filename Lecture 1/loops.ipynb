# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
text = "Это не те прзнаки, которые могли бы служить для подсказки"
new_text = ""
for char in enumerate(text):
    if char[0] % 5 == 0:
        new_text += '*'
    else:
        new_text += char[1]
print(new_text)
# Out:
# *то н* те *рзна*и, к*торы* мог*и бы*служ*ть д*я по*сказ*и
