# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
seven = "7"
int_seven = int(seven)

type(seven), type(int_seven)
# Out:
# (str, int)

# %%
x = 7.0
print(x.is_integer())
print(type(x))
# Out:
# True
# <class 'float'>

# %%
import random

print(random.randint(1,100))
# Out:
# 99

# %%
print(bool(12))
print(bool(''))
print(bool(0))
print(bool([1]))
print(bool((1)))
print(bool({1}))
# Out:
# True
# False
# False
# True
# True
# True

# %% [markdown]
# * All
# * Any

# %%
email = ""
phone = "-1230123"
username = ''
all([email,phone,username])
# Out:
# False

# %%
print( 3 > 1 and 5 < 1)
print(3 > 1 and 5 > 1)

print( 3 > 5 or 5 < 1)
print(3 > 1 or 5 > 1)
# Out:
# False
# True
# False
# True

# %%
x = 5

if x > 0:
    print("A")
elif x > 3:
    print("B")
elif x > 1:
    print("C")
else:
    print("D")
# Out:
# A

# %%
x = 5

if x > 0:
    print("A")

if x > 3:
    print("B")

if x > 10:
    print("C")

else:
    print("D")
# Out:
# A
# B
# D
