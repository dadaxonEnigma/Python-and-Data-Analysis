# %% [markdown]
# ![image.png](attachment:image.png) ![image-2.png](attachment:image-2.png)

# %%
# print("Hi "Python"")
print("Hi \"Python\"")
# print("Path: C:\User\Programs") 
print("Path: C:\\User\\Programs")
# Out:
# Hi "Python"
# Path: C:\User\Programs
