# %% [markdown]
# ## № 35 Чет или нечет

# %%
user_number = int(input('Введите число: '))
even_or_odd = 'Четное' if user_number % 2 == 0 else 'Нечетное'
print(even_or_odd)
# Out:
# Четное

# %% [markdown]
# ## №36 Собачий возраст

# %%
human_age = int(input('Введите возраст'))

if human_age
