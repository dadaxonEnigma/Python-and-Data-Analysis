# %% [markdown]
# ![image.png](attachment:image.png)

# %%
s = 'luffy is still joyboy'
def lengthOfLastWord(s) -> int:
    new_s = s.split()
    return len(''.join(new_s[-1::]))

print(lengthOfLastWord(s))
# Out:
# 6
