# %%
name: str = 'Dadaxon'
age: int = 24
is_developer: bool = True

# %% [markdown]
# ## Анотации Функций

# %%
def greet(name: str, age:int )-> str: # Если функция ничего не возвращает -> None
    return f"Привет, {name}"

# %%
# Типизация list
numbers: list[int] = [1,2,3,4,5]

# Словарь
user_ages: dict[str,int] = {
    'Dadaxon': 25,
    'Anna': 22
}

## Кортеж
user_info: tuple[str, int, float] = ('Алексей', 30, 75.5)
