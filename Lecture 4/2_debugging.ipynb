# %% [markdown]
# ## Интерактивная отладка с помощью pdb

# %%
import pdb

def divide(a,b):
    pdb.set_trace()
    return a / b
print(divide(10,2))
# Out:
# > c:\users\user\appdata\local\temp\ipykernel_16960\1913230593.py(5)divide()
# 5.0

# %%
def divide(a, b):
    result = a / b
    return result

print(divide(10, 2))
print(divide(15, 3))
# Out:
# 5.0
# 5.0

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print('You cant divide by zero !')
# Out:
# You cant divide by zero !

# %%
try:
    x = 10 / 2
except ZeroDivisionError:
    print('You cant divide by zero')
else:
    print('Division successful:', x)
finally:
    print('This block always runs.')
# Out:
# Division successful: 5.0
# This block always runs.

# %%
try:
    number = int('abc')
    result = 10 / number
except ValueError:
    print('That was not a valid number')
except ZeroDivisionError:
    print('Cant divide by zero.')
# Out:
# That was not a valid number

# %%
try:
    x = 1 / 0
except ZeroDivisionError as e:
    print('Error', e)
# Out:
# Error division by zero

# %%
try:
    number = int(input('str'))
    result = 10/ number
except (ValueError, ZeroDivisionError) as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'sda'
