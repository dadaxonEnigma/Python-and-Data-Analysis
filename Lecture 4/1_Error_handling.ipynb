# %% [markdown]
# ## SyntaxError

# %%
# print('Hello world!'

# %% [markdown]
# ## NameError

# %%
# print(name)

# %% [markdown]
# ## TypeError

# %%
# '5' + 5

# %% [markdown]
# ## IndexError

# %% [markdown]
# ## AttributeError
