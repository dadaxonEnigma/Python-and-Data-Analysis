# %%
cities = ['Los Angeles', 'London', 'Tokyo']
cities[0]
cities[-1]
# Out:
# 'Tokyo'

# %%
developer = 'dadax on'
print(list(developer.strip()))
# Out:
# ['d', 'a', 'd', 'a', 'x', ' ', 'o', 'n']

# %%
developer = ['Dadaxon', 23, 'ML Engenieer']
del developer[1]
print(developer)
# Out:
# ['Dadaxon', 'ML Engenieer']
