# %%
class Circle:
    def __init__(self, radius):
        self._radius = radius
    
    @property
    def radius(self):
        return self._radius
    
    @property
    def area(self):
        return 3.14 * (self._radius ** 2)
    
my_circle = Circle(3)

print(my_circle.radius)
print(my_circle.area)
# Out:
# 3
# 28.26

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius # calling the setter

    @property
    def radius(self):
        return self._radius
    
    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError('Radius must be positive')
        self._radius = value

my_circle = Circle(3)
print('Initial radius:', my_circle.radius)

my_circle.radius = 8 # вызывает setter
print('After modif the radius:', my_circle.radius)
# Out:
# Initial radius: 3
# After modif the radius: 8

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius

    # getter
    @property
    def radius(self):
        return self._radius
    # setter
    @radius.setter
    def radius(self, value):
        if value <= 0:
            raise ValueError('Radius must be positive')
        self._radius = value

    # deleter
    @radius.deleter
    def radius(self):
        print('Deleting radius...')
        del self._radius

my_circle = Circle(33)
del my_circle.radius

try:
    print(my_circle.radius)
except AttributeError as e:
    print('Error:', e)
# Out:
# Deleting radius...
# Error: 'Circle' object has no attribute '_radius'

# %% [markdown]
# Из этого следует что:
#
# * Геттеры позволяют получить значние или даже вычислять его на лету
# * Сеттеры позволя.т безопасно изменять значения, выполняя проверки перед присвоением
# * Свойства объединяют геттеры и сеттер, позволяя писать код с испл точечной натации
# * Делитеры позволяют определить, что происходит при удалении атрибута

# %%
class User:
    def __init__(self, age):
        self._age = age  # "защищённое" поле

    @property
    def age(self):  # getter
        return self._age

    @age.setter
    def age(self, value):  # setter
        if value < 0:
            raise ValueError("Возраст не может быть отрицательным")
        self._age = value

# %%
u = User(20)

print(u.age)   # getter вызывается
u.age = 25     # setter вызывается

u.age = -10    # ❌ ошибка
# Out:
# 20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 6
#       3 print(u.age)   # getter вызывается
#       4 u.age = 25     # setter вызывается
# ----> 6 u.age = -10    # ❌ ошибка
#
# Cell In[13], line 12, in User.age(self, value)
#       9 @age.setter
#      10 def age(self, value):  # setter
#      11     if value < 0:
# ---> 12         raise ValueError("Возраст не может быть отрицательным")
#      13     self._age = value
#
# ValueError: Возраст не может быть отрицательным
