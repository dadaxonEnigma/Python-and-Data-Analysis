# %% [markdown]
# # Наследование Python

# %% [markdown]
# Наследование позволяет определить класс, который наслдеуеь все методы и свойств другого класса, но может расширять и модифициовать эту функциональность
# * Родительский класс - это класс, от которого происходит наследование
# * Дочерний класс - это класс, который наследует от другого класса

# %% [markdown]
# ## Зачем исп наследование ?
#
# * Повтороное использвоание кода - избавляет от дублирования.
# * Логическое - ирерахии - отражает естественные оотношения мжду обхектами
# * Расширяемость - легко добавлять новую функциональность

# %%
# Родительский класс 
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        return f'Звук животного'
    
# Дочерний класс
class Dog(Animal): # Dog наследует от Animal
    def speak(self): # Переопределяем метод
        return f'{self.name} говорит Гав!'
    

animal = Animal('Существо')
dog = Dog('Рекс')

print(animal.speak())
print(dog.speak()) # вызывается переопределенный метод
print(dog.name) # атрибут унаследован от родительского класса
# Out:
# Звук животного
# Рекс говорит Гав!
# Рекс

# %%
class Person:
    def __init__(self, fname = 'Dadaxon', lname="Unknown"):
        self.firstname = fname
        self.lastname = lname
    
    def printname(self):
        print(self.firstname, self.lastname)

x = Person('Dadaxon', 'Turgunboev')
x.printname()
# Out:
# Dadaxon Turgunboev

# %% [markdown]
# ## Дочерний класс

# %%
class Student(Person):
    pass # если не хотите добавить свой или методы 

first_student = Student(lname='Olsen')
first_student.printname()
# Out:
# Dadaxon Olsen

# %% [markdown]
# !!! Если добавить функ __init__() дочерний класс больше не будет гаследовать функцию __init__() родительского класса

# %%
class Student(Person):
    def __init__(self, fname, lname):
        self.firstname = fname
        self.lastname = lname
    
second_student = Student('','')
second_student.printname()

# %% [markdown]
# !!! Что бы сохранить наследоваие родит класса

# %%
class Student(Person):
    def __init__(self, fname, lname):
        Person.__init__(self, fname, lname)

# %% [markdown]
# ## Функция super()
#
# Часто требуется расширить функциональность родительского метода, а не полностью заменить. Для этого исп функция super()

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    
    def sound(self):
        return f"{self.name} make a sound"

class Dog(Animal):
    bark = 'wof! woof!! woof!!!'

    # перезаписываем 
    def sound(self):
        return f'{self.name} barks {self.bark}'
    
jack = Dog('Jack')
print(jack.sound())
# Out:
# Jack barks wof! woof!! woof!!!

# %% [markdown]
# Если вы хотите сохранить возвращаемое значение sound() и добваить класса bark позже,
# вы можете расширить sound() с помощью функции super()

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def sound(self):
        return f"{self.name} makes sound"

class Dog(Animal):
    bark = 'woof! woof!! woof!!!'

    # Call Animal.sound(), then append bark
    def sound(self):
        base = super().sound()
        return f'{base}, then {self.name} bark'
jack = Dog('Dog')
print(jack.sound())
# Out:
# Dog makes sound, then Dog bark

# %%
class Vehicle:
    def __init__(self, brand):
        self.brand = brand
    
    def info(self):
        return f"Транспорт марки {self.brand}"
    
class Car(Vehicle):
    def __init__(self, brand, model):
        super().__init__(brand) # вызываем конструктор родителя
        self.model = model

        def info(self):
            # расширяем родительский метод
            return f"{super().info()}, модель {self.model}"
        
car = Car('Tayora', 'Carolla')
print(car.info())
# Out:
# Транспорт марки Tayora

# %% [markdown]
# ## Иерархии наследование

# %%
class Animal:
    def eat(self):
        return 'Животное ест'
    
class Mammal(Animal):
    def breathe(self):
        return 'Дышит легкими'
    
class Dog(Mammal):
    def bark(self):
        return 'Гав!'
    
dog = Dog()
print(dog.eat())
print(dog.breathe())
print(dog.bark())
# Out:
# Животное ест
# Дышит легкими
# Гав!

# %% [markdown]
# ## Добваления свойств

# %%
class Student(Person):
    def __init__(self, fname, lname):
        super().__init__(fname, lname)
        self.graduationyear = 2026

x = Student("Deny", "Olise")
x.graduationyear
# Out:
# 2026

# %%
class Animal:
    def __init__(self, name):
        self.name = name
    def speak(self):
        print(f'{self.name}')

class Dog(Animal):
    pass

d1 = Dog('Rex')
d1.speak()
# Out:
# Rex

# %% [markdown]
# ## Проверка наследования: isinstance() и issubclass()
#
# Python предостовляет полезные функции для проверки отношений наслдеования:

# %%
# Базовый класс - родитель в иерархии
class Vehicle:
    pass

# Дочерние классы - наследуются от Vehicle
class Car(Vehicle):
    pass # Car является разновидностью Vehicle

class Bicycle(Vehicle):
    pass # Bicycle тоже является разновидностью Vehicle


car = Car()
bicycle = Bicycle()

# Првоеряем тип объекта
print(isinstance(car, Car))
# car является экземпляром класса Vehicle (через наследование)?
print(isinstance(car, Vehicle))

# car является экземпляром Bicycle
print(isinstance(car, Bicycle))

# Проверяем отношения между классами
print(issubclass(Car, Vehicle)) # Car является подклассом Vehicle 
print(issubclass(Vehicle, Car)) 
print(issubclass(Bicycle, Vehicle))
# Out:
# True
# True
# False
# True
# False
# True

# %% [markdown]
# ## Абстрактные классы
#
# Абстрактные классы служат как шаблон для создания других классов. Они содержат абстрактные мтеожы, которые должны быть реализованы в подклассах.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

    @abstractmethod
    def perimeter(self):
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
# Попытка создать экземпляр абстрактного класса
try:
    shape = Shape()
except TypeError as e:
    print(f'Ошибка: {e}')

# Создание экземпляра конкретного класса
rect = Rectangle(5,3)
print(f'Площадь {rect.area()}')
# Out:
# Ошибка: Can't instantiate abstract class Shape without an implementation for abstract methods 'area', 'perimeter'
# Площадь 15

# %% [markdown]
# ## Множественное наследование

# %%
class Flying:
    def fly(self):
        return "Я могу летать!"

class Swimming:
    def swim(self):
        return "Я могу плавать!"

# Множественное наследование
class Duck(Flying, Swimming):
    def sound(self):
        return "Кря!"

# Создаем утку
duck = Duck()
print(duck.fly())

print(duck.swim())

print(duck.sound())
# Out:
# Я могу летать!
# Я могу плавать!
# Кря!

# %% [markdown]
# ## порядок разрешения методов
#
# При множественном наследовании важно знать, в каком порядке Python ищет методы в классах. Этот Порядок называется
# Method Resolution Order(MRO)

# %%
class A:
    def method(self):
        return "A"

class B(A):
    def method(self):
        return "B"

class C(A):
    def method(self):
        return "C"

class D(B, C):
    pass

# Проверяем MRO класса D
print(D.__mro__)


# Создаем объект и вызываем метод
d = D()
print(d.method())# Будет вызван метод из B, так как B стоит перед C
# Out:
# (<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>)
# B
